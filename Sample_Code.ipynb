# %% [markdown]
# # Sample Code for the Dataset of Tensile Properties of Sub-sized Specimens

# %% [markdown]
# This notebook provides simple Python code for loading the dataset of tensile properties of sub-sized specimens.
#
# The code was developed as a supplementary material for the following manuscript that is currently under review by Scientific Data:
# * Longze Li, John W. Merickel, Yalei Tang, Rongjie Song, Joshua E. Rittenhouse, Aleksandar Vakanski, and Fei Xu, "Dataset of Tensile Properties for Sub-sized Specimens of Nuclear Structural Materials," submitted to *Scientific Data*, under review, 2024.
#
# The dataset is stored in the Excel file titled `"Tensile_Properties_of_Sub-sized_Specimens.xlsx."`
#
# The code demonstrates how to load the dataset into a pandas dataframe, and also provides examples of exploratory data analysis and visualization of features in the dataset.
#
# - [1. Loading the Dataset](#1.-loading-the-dataset)
# - [2. Visualizing the Distribution of Features in the Dataset](#2.-visualizing-the-distribution-of-features-in-the-dataset)
#     - [2.1 Sub-sized Specimen Dimensions](#2.1-sub-sized-specimen-dimensions)
#     - [2.2 Tensile Properties](#2.2-tensile-properties)
#     - [2.3 Manufacturing Treatment and Irradiation Conditions](#2.3-manufacturing-treatment-and-irradiation-conditions)
#     - [2.4 Technical Validation](#2.4-technical-validation)

# %% [markdown]
# # 1. Loading the dataset <a name='1.-loading-the-dataset'></a>

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the data as pandas dataframe
tensile_df =  pd.read_excel("Tensile_Properties_of_Sub-sized_Specimens.xlsx", header=0, skiprows=1)
tensile_df
# Out:
#       Reference Material         Material Group C (wt.%)  Si (wt.%)  \
# 0             1   SS304L  NSM, Rector Internals     0.02       0.45
# 1             1   SS304L  NSM, Rector Internals     0.02       0.45
# 2             1   FeCrAl     NSM, Fuel Cladding      NaN       0.13
# 3             1   FeCrAl     NSM, Fuel Cladding      NaN       0.13
# 4             1   FeCrAl     NSM, Fuel Cladding      NaN       0.13
# ...         ...      ...                    ...      ...        ...
# 1065         27    SS304  NSM, Rector Internals    0.058       0.36
# 1066         27   SS304L  NSM, Rector Internals    0.018       0.38
# 1067         27   SS304L  NSM, Rector Internals    0.018       0.38
# 1068         27   SS304L  NSM, Rector Internals    0.018       0.38
# 1069         27   SS304L  NSM, Rector Internals    0.018       0.38
#
#       Mn (wt.%)  P (wt.%)  S (wt.%)  Ni (wt.%)  Cr (wt.%)  ...  Width (mm)  \
# 0          1.30       NaN       NaN       8.02      18.30  ...         1.2
# 1          1.30       NaN       NaN       8.02      18.30  ...         0.8
# 2           NaN       NaN       NaN        NaN      13.10  ...         1.2
# 3           NaN       NaN       NaN        NaN      13.10  ...         0.8
# 4           NaN       NaN       NaN        NaN      13.10  ...         0.8
# ...         ...       ...       ...        ...        ...  ...         ...
# 1065       1.73     0.026     0.250       8.78      17.67  ...         NaN
# 1066       1.52     0.033     0.002      10.10      18.04  ...         NaN
# 1067       1.52     0.033     0.002      10.10      18.04  ...         NaN
# 1068       1.52     0.033     0.002      10.10      18.04  ...         NaN
# 1069       1.52     0.033     0.002      10.10      18.04  ...         NaN
#
#       Aspect Ratio (L/W)  Aspect Ratio (R/W)  Aspect Ratio (T/W)  \
# 0                 4.1667              1.1667               0.625
# 1                 4.4375              0.3750               0.500
# 2                 4.1667              1.1667               0.625
# 3                 3.1875              0.3750               0.500
# 4                 3.1875              0.3750               0.500
# ...                  ...                 ...                 ...
# 1065                 NaN                 NaN                 NaN
# 1066                 NaN                 NaN                 NaN
# 1067                 NaN                 NaN                 NaN
# 1068                 NaN                 NaN                 NaN
# 1069                 NaN                 NaN                 NaN
#
#      Test Temperature (C)  Strain Rate (1/s)  Yield Strength (MPa)  \
# 0                    23.0           0.001000                 274.0
# 1                    23.0           0.001000                 272.0
# 2                    23.0           0.001000                 710.0
# 3                    23.0           0.001000                 607.0
# 4                    23.0           0.001000                 725.0
# ...                   ...                ...                   ...
# 1065                 23.0           0.001666                 555.0
# 1066                 23.0           0.001666                 269.0
# 1067                 23.0           0.001666                 278.0
# 1068                 23.0           0.001666                 315.0
# 1069                 23.0           0.001666                 305.0
#
#       Ultimate Tensile Strength (MPa)  Uniform Elongation (%)  \
# 0                               789.0                    67.0
# 1                               781.0                    69.0
# 2                               767.0                     7.9
# 3                               760.0                    10.8
# 4                               782.0                     6.6
# ...                               ...                     ...
# 1065                            784.0                     NaN
# 1066                            595.0                     NaN
# 1067                            595.0                     NaN
# 1068                            641.0                     NaN
# 1069                            632.0                     NaN
#
#       Total Elongation (%)
# 0                     76.0
# 1                     80.0
# 2                     14.8
# 3                     23.1
# 4                     18.2
# ...                    ...
# 1065                   NaN
# 1066                   NaN
# 1067                   NaN
# 1068                   NaN
# 1069                   NaN
#
# [1070 rows x 54 columns]

# %%
# Check the data information for each column
tensile_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1070 entries, 0 to 1069
# Data columns (total 54 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Reference                        1070 non-null   int64
#  1   Material                         1070 non-null   object
#  2   Material Group                   1070 non-null   object
#  3   C (wt.%)                         807 non-null    object
#  4   Si (wt.%)                        774 non-null    float64
#  5   Mn (wt.%)                        776 non-null    float64
#  6   P (wt.%)                         754 non-null    float64
#  7   S (wt.%)                         562 non-null    float64
#  8   Ni (wt.%)                        987 non-null    float64
#  9   Cr (wt.%)                        1004 non-null   float64
#  10  Mo (wt.%)                        927 non-null    float64
#  11  Al (wt.%)                        72 non-null     float64
#  12  N (wt.%)                         402 non-null    float64
#  13  Ti (wt.%)                        358 non-null    float64
#  14  Fe (wt.%)                        991 non-null    object
#  15  Nb (wt.%)                        337 non-null    float64
#  16  B (wt.%)                         337 non-null    float64
#  17  Cu (wt.%)                        339 non-null    float64
#  18  V (wt.%)                         272 non-null    float64
#  19  Mg (wt.%)                        10 non-null     float64
#  20  Y (wt.%)                         9 non-null      float64
#  21  Zr (wt.%)                        30 non-null     object
#  22  Zn (wt.%)                        4 non-null      float64
#  23  W (wt.%)                         12 non-null     float64
#  24  Sn (wt.%)                        15 non-null     float64
#  25  Co (wt.%)                        202 non-null    float64
#  26  O (wt.,%)                        110 non-null    object
#  27  Ta (wt.%)                        72 non-null     float64
#  28  H (wt.%)                         11 non-null     float64
#  29  Manufacturing                    104 non-null    object
#  30  Treatment                        403 non-null    object
#  31  Treatment – Three Categories     793 non-null    object
#  32  Post Treatment Temperature (C)   116 non-null    float64
#  33  Post Treatment Time (h)          115 non-null    float64
#  34  Cooling                          35 non-null     object
#  35  Microstructure                   11 non-null     object
#  36  Grain size (um)                  765 non-null    float64
#  37  Irradiation Dose (mdpa)          321 non-null    float64
#  38  Irradiation Temperature (C)      321 non-null    float64
#  39  Irradiation Time (h)             1 non-null      float64
#  40  Specimen Size Type               504 non-null    object
#  41  Gauge Length (mm)                761 non-null    float64
#  42  Thickness (mm)                   881 non-null    float64
#  43  Fillet Radius (mm)               166 non-null    float64
#  44  Width (mm)                       760 non-null    float64
#  45  Aspect Ratio (L/W)               741 non-null    float64
#  46  Aspect Ratio (R/W)               149 non-null    float64
#  47  Aspect Ratio (T/W)               831 non-null    float64
#  48  Test Temperature (C)             982 non-null    float64
#  49  Strain Rate (1/s)                957 non-null    float64
#  50  Yield Strength (MPa)             606 non-null    float64
#  51  Ultimate Tensile Strength (MPa)  505 non-null    float64
#  52  Uniform Elongation (%)           253 non-null    float64
#  53  Total Elongation (%)             537 non-null    float64
# dtypes: float64(41), int64(1), object(12)
# memory usage: 451.5+ KB

# %% [markdown]
# # 2. Visualizing the Distribution of Features in the Dataset <a name='2.-visualizing-the-distribution-of-features-in-the-dataset'></a>

# %% [markdown]
# ## 2.1 Sub-sized Specimen Dimensions <a name='2.1-sub-sized-specimen-dimensions'></a>

# %%
# Histogram of Gauge Length (Figure 5a)
plt.rcParams.update({'font.size': 14.0})
fig1, ax1 = plt.subplots()
tensile_df['Gauge Length (mm)'].dropna().hist(bins=20, linewidth=0.5, color='lightgreen', edgecolor='red')
ax1.set_xlabel('Gauge Length (mm)')
ax1.set_ylabel('Frequency')
plt.grid(False)
plt.show()

# %%
# Histogram of Thickness (Figure 5b)
fig2, ax2 = plt.subplots()
tensile_df['Thickness (mm)'].dropna().hist(bins=20, linewidth=0.5,color='lightgreen', edgecolor='red')
ax2.set_xlabel('Thickness (mm)')
ax2.set_ylabel('Frequency')
plt.grid(False)
plt.show()

# %%
# Histogram of Width (Figure 5c)
fig3, ax3 = plt.subplots()
tensile_df['Width (mm)'].dropna().hist(bins=20, color='lightgreen',linewidth=0.5, edgecolor='red')
ax3.set_xlabel('Width (mm)')
ax3.set_ylabel('Frequency')
plt.grid(False)
plt.show()

# %% [markdown]
# ## 2.2 Tensile Properties <a name='2.2-tensile-properties'></a>

# %%
# Histogram of Yield Strength (Figure 6a)
bin_edges = numbers = list(range(0, 1401, 100))
fig4, ax4 = plt.subplots()
ax4.set_xlabel('Yield Strength (MPa)')
ax4.set_ylabel('Frequency')
hist, edges = np.histogram(tensile_df['Yield Strength (MPa)'].dropna(), bins=bin_edges)
bin_centers = (edges[:-1] + edges[1:]) / 2
plt.bar(bin_centers, hist, width=100, linewidth=0.5, color='skyblue', edgecolor='black') 
plt.grid(False)
plt.xlim(0, 1400)
plt.show()

# %%
# Histogram of Ultimate Tensile Strength (Figure 6b)
bin_edges = numbers = list(range(0, 1401, 100))
fig5, ax5 = plt.subplots()
ax5.set_xlabel('Ultimate Tensile Strength (MPa)')
ax5.set_ylabel('Frequency')
hist, edges = np.histogram(tensile_df['Ultimate Tensile Strength (MPa)'].dropna(), bins=bin_edges)
bin_centers = (edges[:-1] + edges[1:]) / 2
plt.bar(bin_centers, hist, width=100, linewidth=0.5, color='skyblue', edgecolor='black') 
plt.grid(False)
plt.xlim(0, 1400)
plt.show()

# %%
# Histogram of Uniform Elongation (Figure 6c)
bin_edges = numbers = list(range(0, 120, 5))
fig6, ax6 = plt.subplots()
ax6.set_xlabel('Uniform Elongation (%)')
ax6.set_ylabel('Frequency')
hist, edges = np.histogram(tensile_df['Uniform Elongation (%)'].dropna(), bins=bin_edges)
bin_centers = (edges[:-1] + edges[1:]) / 2
plt.bar(bin_centers, hist, width=5, linewidth=0.5, color='skyblue', edgecolor='black') 
plt.grid(False)
plt.xlim(0, 120)
plt.show()

# %%
# Histogram of Total Elongation (Figure 6d)
bin_edges = numbers = list(range(0, 120, 5))
fig7, ax7 = plt.subplots()
ax7.set_xlabel('Total Elongation (%)')
ax7.set_ylabel('Frequency')
hist, edges = np.histogram(tensile_df['Total Elongation (%)'].dropna(), bins=bin_edges)
bin_centers = (edges[:-1] + edges[1:]) / 2
plt.bar(bin_centers, hist, width=5, linewidth=0.5, color='skyblue', edgecolor='black') 
plt.grid(False)
plt.xlim(0, 120)
plt.show()

# %% [markdown]
# ## 2.3 Manufacturing Treatment and Irradiation Conditions <a name='2.3-manufacturing-treatment-and-irradiation-conditions'></a>

# %%
# Histogram of Manufacturing Treatment (Figure 7a)

# Count the occurrences of each category of treatment
category_counts = tensile_df['Treatment – Three Categories'].value_counts()
# Sort the counts in ascending order
sorted_category_counts = category_counts.sort_values(ascending=True)
# Create a bar plot to visualize a sorted histogram
fig8, ax8 = plt.subplots()
ax8.bar(sorted_category_counts.index, sorted_category_counts.values, color='slategrey', linewidth=0.5, edgecolor='black', width=0.23)
ax8.set_xlabel('Manufacturing Treatment')
ax8.set_ylabel('Frequency')
ax8.grid(False)
plt.show()

# %%
# Histogram of Irradiation Dose (Figure 7b)
fig9, ax9 = plt.subplots()
tensile_df['Irradiation Dose (mdpa)'].dropna().hist(bins=10, color='slategrey',linewidth=0.5, edgecolor='black')
ax9.set_xlabel('Irradiation dose (mdpa)')
ax9.set_ylabel('Frequency')
plt.grid(False)
plt.show()

# %%
# Histogram of Irradiation Temperature (Figure 7c)
fig10, ax10 = plt.subplots()
tensile_df['Irradiation Temperature (C)'].dropna().hist(bins=10, color='slategrey',linewidth=0.5, edgecolor='black')
ax10.set_xlabel('Irradiation Temperature (C)')
ax10.set_ylabel('Frequency')
plt.grid(False)
plt.show()

# %% [markdown]
# ## 2.4 Technical Validation <a name='2.4-technical-validation'></a>

# %%
# Histogram of Width to Thickness Ratio (Figure 8a)
df_l_a = tensile_df[['Gauge Length (mm)', 'Thickness (mm)', 'Width (mm)']].dropna()
aspect_ratio_w_to_t = df_l_a['Width (mm)']/df_l_a['Thickness (mm)']
fig11, ax11 = plt.subplots()
aspect_ratio_w_to_t.hist(bins=20, color='darkolivegreen', edgecolor='black', linewidth = 0.5)
ax11.set_xlabel('Width-to-Thickness Ratio')
ax11.set_ylabel('Frequency')
plt.grid(False)
plt.show()

# %%
# Histogram of Gauge Length to Square Root of the Area Ratio (Figure 8b)
aspect_ratio_l0_ao = df_l_a['Gauge Length (mm)']/np.sqrt(df_l_a['Thickness (mm)']*df_l_a['Width (mm)'])
fig12, ax12 = plt.subplots()
aspect_ratio_l0_ao.hist(bins=20, color='darkolivegreen', edgecolor='black', linewidth = 0.5)
ax12.set_xlabel('Length-to-Square_Root_of_Area Ratio')
ax12.set_ylabel('Frequency')
plt.grid(False)
plt.show()

# %%
# Histogram of Gauge length to Width Ratio (Figure 8c)
aspect_ratio_l0_w = df_l_a['Gauge Length (mm)']/df_l_a['Width (mm)']
fig13, ax13 = plt.subplots()
aspect_ratio_l0_w.hist(bins=20, color='darkolivegreen', edgecolor='black', linewidth = 0.5)
ax13.set_xlabel('Gauge Length-to-Width Ratio')
ax13.set_ylabel('Frequency')
plt.grid(False)
plt.show()
